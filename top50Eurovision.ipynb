# %%
from bs4 import BeautifulSoup

# %%
import requests

r = requests.get('https://eurovision.tv/story/top-50', headers={'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Mobile Safari/537.36'})
r.status_code
# Out:
# 200

# %%
html = r.content

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
song = [elem.get_text().split('–') for elem in soup.find("ol").findAll('p')]

# %%
song = [s for s in song if len(s) == 2]

# %%
song
# Out:
# [['ABBA ', ' Waterloo 🇸🇪'],
#  ['Loreen ', ' Euphoria 🇸🇪'],
#  ['Måns Zelmerlöw ', ' Heroes 🇸🇪'],
#  ['Alexander Rybak ', ' Fairytale 🇳🇴'],
#  ['Duncan Laurence ', ' Arcade 🇳🇱'],
#  ['Mahmood ', ' Soldi 🇮🇹'],
#  ['Lena ', ' Satellite 🇩🇪'],
#  ['Conchita Wurst ', ' Rise Like a Phoenix 🇦🇹'],
#  ['Johnny Logan ', ' Hold Me Now 🇮🇪'],
#  ['Lordi ', ' Hard Rock Hallelujah 🇫🇮'],
#  ['Eleni Foureira ', ' Fuego 🇨🇾'],
#  ['Katrina and the Waves ', ' Love Shine a Light 🇬🇧'],
#  ['Céline Dion ', ' Ne partez pas sans moi 🇨🇭'],
#  ['Nicole ', ' Ein bißchen Frieden 🇩🇪'],
#  ['Il Volo ', ' Grande amore 🇮🇹'],
#  ['Salvador Sobral ', ' Amar pelos dois 🇵🇹'],
#  ['Johnny Logan ', ' What’s Another Year 🇮🇪'],
#  ['The Common Linnets ', ' Calm After the Storm 🇳🇱'],
#  ['Olsen Brothers ', ' Fly on the Wings of Love 🇩🇰'],
#  ['Brotherhood of Man ', ' Save Your Kisses for Me 🇬🇧'],
#  ['Umberto Tozzi & Raf ', ' Gente di mare 🇮🇹'],
#  ['Helena Paparizou ', ' My Number One 🇬🇷'],
# ...

# %%
songs = []
artists = []
for a, s in song:
    print(a, s)
    songs.append(' '.join(s.strip().split()[:-1]))
    artists.append(a.strip())
# Out:
# ABBA   Waterloo 🇸🇪
# Loreen   Euphoria 🇸🇪
# Måns Zelmerlöw   Heroes 🇸🇪
# Alexander Rybak   Fairytale 🇳🇴
# Duncan Laurence   Arcade 🇳🇱
# Mahmood   Soldi 🇮🇹
# Lena   Satellite 🇩🇪
# Conchita Wurst   Rise Like a Phoenix 🇦🇹
# Johnny Logan   Hold Me Now 🇮🇪
# Lordi   Hard Rock Hallelujah 🇫🇮
# Eleni Foureira   Fuego 🇨🇾
# Katrina and the Waves   Love Shine a Light 🇬🇧
# Céline Dion   Ne partez pas sans moi 🇨🇭
# Nicole   Ein bißchen Frieden 🇩🇪
# Il Volo   Grande amore 🇮🇹
# Salvador Sobral   Amar pelos dois 🇵🇹
# Johnny Logan   What’s Another Year 🇮🇪
# The Common Linnets   Calm After the Storm 🇳🇱
# Olsen Brothers   Fly on the Wings of Love 🇩🇰
# Brotherhood of Man   Save Your Kisses for Me 🇬🇧
# Umberto Tozzi & Raf   Gente di mare 🇮🇹
# Helena Paparizou   My Number One 🇬🇷
# KEiiNO   Spirit in the Sky 🇳🇴
# Ruslana   Wild Dances 🇺🇦
# Milk and Honey   Hallelujah 🇮🇱
# Dana International   Diva 🇮🇱
# Emmelie de Forest   Only Teardrops 🇩🇰
# Marija Šerifović   Molitva 🇷🇸
# ...

# %%
artists
# Out:
# ['ABBA',
#  'Loreen',
#  'Måns Zelmerlöw',
#  'Alexander Rybak',
#  'Duncan Laurence',
#  'Mahmood',
#  'Lena',
#  'Conchita Wurst',
#  'Johnny Logan',
#  'Lordi',
#  'Eleni Foureira',
#  'Katrina and the Waves',
#  'Céline Dion',
#  'Nicole',
#  'Il Volo',
#  'Salvador Sobral',
#  'Johnny Logan',
#  'The Common Linnets',
#  'Olsen Brothers',
#  'Brotherhood of Man',
#  'Umberto Tozzi & Raf',
#  'Helena Paparizou',
#  'KEiiNO',
#  'Ruslana',
#  'Milk and Honey',
#  'Dana International',
#  'Emmelie de Forest',
#  'Marija Šerifović',
#  'Sandie Shaw',
#  'France Gall',
#  'Mocedades',
#  'Verka Serduchka',
#  'Bucks Fizz',
#  'Dana',
#  'Cliff Richard',
#  'Sandra Kim',
#  'Netta',
#  'Loïc Nottet',
#  'Blanche',
#  'Polina Gagarina',
#  'Toto Cutugno',
#  'Domenico Modugno',
#  'Sergey Lazarev',
#  'Anne-Marie David',
#  'Francesco Gabbani',
#  'Udo Jürgens',
#  'Dschinghis Khan',
#  'Sertab Erener',
#  'Teach-In']

# %%
import pandas as pd
df = pd.DataFrame(list(zip(songs, artists)),
               columns =['Songs', 'Artists'])
df
# Out:
#                             Songs                Artists
# 0                        Waterloo                   ABBA
# 1                        Euphoria                 Loreen
# 2                          Heroes         Måns Zelmerlöw
# 3                       Fairytale        Alexander Rybak
# 4                          Arcade        Duncan Laurence
# 5                           Soldi                Mahmood
# 6                       Satellite                   Lena
# 7             Rise Like a Phoenix         Conchita Wurst
# 8                     Hold Me Now           Johnny Logan
# 9            Hard Rock Hallelujah                  Lordi
# 10                          Fuego         Eleni Foureira
# 11             Love Shine a Light  Katrina and the Waves
# 12         Ne partez pas sans moi            Céline Dion
# 13            Ein bißchen Frieden                 Nicole
# 14                   Grande amore                Il Volo
# ...
